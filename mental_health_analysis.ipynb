# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikesansg-glitch/MindScope-Social-Media-Mental-Health-Analytics/blob/main/mental_health_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment

import pandas as pd
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

posts = {
    "text": [
        "I feel stressed about exams",
        "Today was a beautiful day",
        "I feel anxious and lonely",
        "I am motivated and productive"
    ]
}

df = pd.DataFrame(posts)

analyzer = SentimentIntensityAnalyzer()

def detect_sentiment(text):
    score = analyzer.polarity_scores(text)["compound"]

    if score >= 0.05:
        return "Positive"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"

df["sentiment"] = df["text"].apply(detect_sentiment)

print(df)

df["sentiment"].value_counts().plot(kind="bar")

plt.title("Mental Health Sentiment Analysis")
plt.show()
# Out:
# ...
#                             text sentiment
# 0    I feel stressed about exams  Negative
# 1      Today was a beautiful day  Positive
# 2      I feel anxious and lonely  Negative
# 3  I am motivated and productive  Positive
